# %%
#### Here i m going to write prompts ############

## and lets learn HOw to write Prompts ######


### GPT , GROK 


###

# %%
#### Create end to end pipeline ######
'''
 I want to develop end to end data enginnering pipeline using AWS CLOUD
 I want to use Kafka , GLUE OR EMR, REDSHIFT 
 I want to create bronze, silver , gold layer
 This project i want to create for mcafee antivirus compnay
 Help me building it completely for DEV/STG/PROD enviorment 
 I want to create complete automation CI/CD process 
'''

# %%
### Help me Building A Data enginnering solution END To END pipeling 
'''
I have a source where everyday 40k-50k csv files are pushed , i need to read that source and keep those csv file in S3 Bucket
Once CSV files are available in S3 , I need to run GLUE job which reads all csv file convert into parquet file format and parition with year, month , day
there is caveat that each csv file has either 1 columns, 2 column , 50 column , or 100 columns , 
so one of task is too align each each and every csv then write to transformed Layer(S3)
From there we will run COPY command and place into redshift 
 from there QUicksight will read and give some insights
I want you to develop this usecase end to end , take any dataaset and deveop this solution 
'''

### 
'''
 IN glue etl job  , there is challenge 
 I have csv from source , where order of csv isnt sure 

 file1.csv 
 ------------
 col1,col2,col3 
 val1,val2,val3

  file2.csv 
 ------------
 col2,col1,col2
 val2,val1,val3

 How do we tackle that
'''
